# %%
import pandas as pd

# Load the uploaded CSV
file_path = r'C:\Users\badsh\OneDrive\Desktop\CLEF_2026_Humour_Project\results\final_metrics_comparison.csv'
df = pd.read_csv(file_path)

df
# Out:
#             Unnamed: 0       MAP    nDCG@5       P@1       P@5      P@10  \
# 0                 BM25  0.132364  0.243102  0.250000  0.250000  0.216667
# 1                  RM3  0.111243  0.260431  0.416667  0.233333  0.191667
# 2                Dense  0.037875  0.077674  0.083333  0.083333  0.125000
# 3  Dense-Minilm-Cosine  0.051275  0.077674  0.083333  0.083333  0.125000
# 4               Hybrid  0.130736  0.232168  0.250000  0.233333  0.216667
# 5         Hybrid-Tuned  0.130736  0.232168  0.250000  0.233333  0.216667
# 6        Cross-Encoder  0.324239  0.721620  0.833333  0.683333  0.525000
#
#    Recall@5  Recall@10       MRR     bpref  ResultQueries  LabeledQueries  \
# 0  0.074509   0.126812  0.423077  0.129861          219.0            12.0
# 1  0.057506   0.100942  0.474681  0.093568          219.0            12.0
# 2  0.002431   0.042087  0.165806  0.031467          219.0            12.0
# 3  0.002431   0.042087  0.165806  0.037144          219.0            12.0
# 4  0.065250   0.126812  0.421688  0.125590          219.0            12.0
# 5  0.065250   0.126812  0.421688  0.125590          219.0            12.0
# 6  0.243338   0.334856  0.833333  0.327496          219.0            12.0
#
#    LabeledQueryCoverage
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# 5                   1.0
# 6                   1.0

# %%
import matplotlib.pyplot as plt

# Clean column name
df = df.rename(columns={'Unnamed: 0': 'Model'})

# Plot MAP comparison
plt.figure()
plt.plot(df['Model'], df['MAP'], marker='o')
plt.title('MAP Comparison Across Models')
plt.xlabel('Model')
plt.ylabel('MAP')
plt.xticks(rotation=45)

plt.show()
