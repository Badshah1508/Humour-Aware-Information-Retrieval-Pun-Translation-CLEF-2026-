# %%
import pandas as pd

# Load the uploaded CSV
file_path = r'C:\Users\badsh\OneDrive\Desktop\CLEF_2026_Humour_Project\results\final_metrics_comparison.csv'
df = pd.read_csv(file_path)

df
# Out:
#                 Unnamed: 0       MAP    nDCG@5       P@1       P@5      P@10  \
# 0                     BM25  0.040587  0.243102  0.250000  0.250000  0.125000
# 1                      RM3  0.046986  0.260431  0.416667  0.233333  0.116667
# 2                    Dense  0.008479  0.077674  0.083333  0.083333  0.125000
# 3                   Hybrid  0.039447  0.228970  0.250000  0.233333  0.116667
# 4            Cross-Encoder  0.030962  0.199986  0.083333  0.233333  0.116667
# 5  Cross-Encoder-Finetuned  0.032096  0.209346  0.083333  0.233333  0.116667
#
#    Recall@5  Recall@10       MRR     bpref
# 0  0.074509   0.074509  0.409722  0.057731
# 1  0.057506   0.057506  0.458333  0.052236
# 2  0.002431   0.042087  0.151620  0.017345
# 3  0.072372   0.072372  0.398611  0.055649
# 4  0.072372   0.072372  0.270833  0.053451
# 5  0.072372   0.072372  0.298611  0.053728

# %%
import matplotlib.pyplot as plt

# Clean column name
df = df.rename(columns={'Unnamed: 0': 'Model'})

# Plot MAP comparison
plt.figure()
plt.plot(df['Model'], df['MAP'], marker='o')
plt.title('MAP Comparison Across Models')
plt.xlabel('Model')
plt.ylabel('MAP')
plt.xticks(rotation=45)

plt.show()
