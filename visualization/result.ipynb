# %%
import pandas as pd

# Load the uploaded CSV
file_path = r'C:\Users\badsh\OneDrive\Desktop\CLEF_2026_Humour_Project\results\final_metrics_comparison.csv'
df = pd.read_csv(file_path)

df
# Out:
#                 Unnamed: 0       MAP    nDCG@5       P@1       P@5      P@10  \
# 0                     BM25  0.132364  0.243102  0.250000  0.250000  0.216667
# 1                      RM3  0.111243  0.260431  0.416667  0.233333  0.191667
# 2                    Dense  0.037875  0.077674  0.083333  0.083333  0.125000
# 3                   Hybrid  0.039447  0.228970  0.250000  0.233333  0.116667
# 4            Cross-Encoder  0.030962  0.199986  0.083333  0.233333  0.116667
# 5  Cross-Encoder-Finetuned  0.037460  0.190895  0.166667  0.183333  0.158333
#
#    Recall@5  Recall@10       MRR     bpref
# 0  0.074509   0.126812  0.423077 -0.181150
# 1  0.057506   0.100942  0.474681 -0.311989
# 2  0.002431   0.042087  0.165806 -0.519832
# 3  0.072372   0.072372  0.398611  0.055649
# 4  0.072372   0.072372  0.270833  0.053451
# 5  0.048916   0.063636  0.305556  0.053707

# %%
import matplotlib.pyplot as plt

# Clean column name
df = df.rename(columns={'Unnamed: 0': 'Model'})

# Plot MAP comparison
plt.figure()
plt.plot(df['Model'], df['MAP'], marker='o')
plt.title('MAP Comparison Across Models')
plt.xlabel('Model')
plt.ylabel('MAP')
plt.xticks(rotation=45)

plt.show()
